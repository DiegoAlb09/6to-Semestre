# %% [markdown]
# # Universidad Autonoma de Aguascalientes
# ## Departamento: Ciencias de la Computación
# ## Carra: Ingenieria en Computación Inteligente
# ### Curso: Aprendizaje Inteligente (Machine Learning)
# ### Maestro: Dr. Francisco Javier Luna Rosas
# ### Alumno: Diego Alberto Aranda Gonzalez
# ### Semestre: Enero_Junio del 2024

# %% [markdown]
# #### Practica No. 3 Visualizacion de Datos

# %% [markdown]
# #### Librerias

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ##### Datos del eje x para los siguientes gráficos

# %%
x = np.linspace(0, 10, 100)
print(x)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %% [markdown]
# ##### Ejemplos de gráficos de lineas (graficando funciones)

# %% [markdown]
# ###### Nota: Lo siguiente se ejecuta todo junto

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %% [markdown]
# ##### Paneles de Graficos

# %%
plt.figure() # crear la figura
#Crear el primer plano
plt.subplot (2, 1, 1) # (filas, columnas, panel)
plt.plot(x, np.sin(x))
#Crear el segundo plano
plt.subplot (2, 1, 2)
plt.plot(x, np.cos(x))

# %% [markdown]
# ##### Un estilo Orientado a Objetos para situaciones más complejas

# %%
fig, ax = plt.subplots(2)
#Llama el metodo plot() method
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# ##### Usando Colores (onda senoidal)

# %%
plt.plot(x, np.sin(x - 0), color='blue') # Nombre del color
plt.plot(x, np.sin(x - 1), color='g') # codigo del color (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Escala de grises entre 0 y 1
#plt.plot(x, np.sin(x - 3), color='#FFDD44') # codigo hexadecimal (RRGGBB de 00 a FF)
#plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # Tupla RGB de 0 a 1
#plt.plot(x, np.sin(x - 5), color='chartreuse') # soporta todos los nombres de HTML

# %% [markdown]
# ##### Usando colores (lineas)

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted')

# %% [markdown]
# ##### Usando Colores (lineas). Lo mismo pero con codigo

# %%
plt.plot(x, x + 4, linestyle='-') # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':') # dotted

# %% [markdown]
# ##### Cambiamos los limites

# %%
plt.plot(x,np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# ##### Titulos

# %%
plt.plot(x,np.sin(x))
plt.title("Funcion Seno")
plt.xlabel("x")
plt.ylabel("sin(x)")
# Out:
# Text(0, 0.5, 'sin(x)')

# %% [markdown]
# ##### Leyendas

# %%
plt.plot(x,np.sin(x), '-g', label='Seno(x)')
plt.plot(x,np.cos(x), ':b', label='Coseno(x)')
plt.legend(loc='upper right')

# %% [markdown]
# ##### Ejemplos con los Datos de Iris

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("C:/Users/diego/Desktop/Universidad/6to-Semestre/Aprendizaje_Inteligente/iris.csv",delimiter=";",decimal=".")
print(df.shape)
print(df.head())
# Out:
# (150, 5)
#    s.largo  s.ancho  p.largo  p.ancho    tipo
# 0      5.1      3.5      1.4      0.2  setosa
# 1      4.9      3.0      1.4      0.2  setosa
# 2      4.7      3.2      1.3      0.2  setosa
# 3      4.6      3.1      1.5      0.2  setosa
# 4      5.0      3.6      1.4      0.2  setosa

# %% [markdown]
# ##### Elimina la variable categoria, deja las variables predictorias en X (Setosa y Versicolor)

# %%
X = df.iloc[0:100, [0,2]].values

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:50, 0], X[:50, 1], color='red', marker='o', label='setosa')
plt.scatter(X[50:100, 0], X[50:100, 1], color='blue', marker='x', label='versicolor')

plt.xlabel('sepal length [cm]')
plt.ylabel('petal length [cm]')

plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# ##### En esta practica utilizamos matplotlib.pyplot para visualizar datos de apredizaje automatico (conocido en el idioma ingles Machine Learning) para clasificar las clases qeu son linealmente separables. Las clases son de la flor de iris, las caracteristicas que se tomaron en cuenta son longitud de petalo y longitud del sefalo.

# %% [markdown]
# ### Bibliografia.
# #### [1] URL: SCIKIT-LEARN (Machine Learning in Python 2024). https://scikit-learn.org/stable/
# #### [2] Sebastian Raschka, Vahid Mirjalili (2019). Machine Learning, Editorail Marcombo, Madrid, España. URL: www.marcombo.info. ISBN: 978-84-267-2720-6
