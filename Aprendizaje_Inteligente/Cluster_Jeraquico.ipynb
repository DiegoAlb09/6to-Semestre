# %%
install.packages("FactoMineR")
# Out:
# Installing package into 'C:/Users/diego/AppData/Local/R/win-library/4.3'
# (as 'lib' is unspecified)
#
# also installing the dependencies 'diffobj', 'rematch2', 'rappdirs', 'brio', 'praise', 'waldo', 'cachem', 'htmltools', 'memoise', 'mime', 'sass', 'testthat', 'bslib', 'fontawesome', 'tinytex', 'broom', 'SparseM', 'MatrixModels', 'minqa', 'nloptr', 'RcppEigen', 'rmarkdown', 'later', 'carData', 'abind', 'pbkrtest', 'quantreg', 'lme4', 'htmlwidgets', 'httpuv', 'crosstalk', 'jquerylib', 'promises', 'estimability', 'mvtnorm', 'car', 'DT', 'emmeans', 'flashClust', 'leaps', 'multcompView', 'scatterplot3d', 'ggrepel'
